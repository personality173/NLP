# %% [markdown]
# # This is Koshkimbayeva Zhaniya's NLP Week-13 Homework

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import pandas as pd
import re

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Embedding
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# from google.colab import drive
# drive.mount('/content/drive/Data')

# %%
# os.getcwd()
# os.listdir()

# %%
with open('train_positive.txt', 'r', encoding='utf-8') as f:
    texts_true = f.read().splitlines()

with open('train_negative.txt', 'r', encoding='utf-8') as f:
    texts_false = f.read().splitlines()

texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false

print("Positive:", count_true)
print("Negative:", count_false)
print("Total:", total_lines)

maxWordsCount = 10000

tokenizer = Tokenizer(
    num_words=maxWordsCount,
    oov_token="<UNK>",
    filters='!–"—#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»',
    lower=True,
    split=' ',
    char_level=False
)

tokenizer.fit_on_texts(texts)

print("Example word counts:", list(tokenizer.word_counts.items())[:10])
print("First text sample:", texts[0])

max_text_len = 100

data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)

print("Data shape:", data_pad.shape)

Y = np.array([[1, 0]] * count_true + [[0, 1]] * count_false)

# Shuffle dataset
indices = np.random.permutation(len(texts))
X = data_pad[indices]
Y = Y[indices]

print("X shape:", X.shape)
print("Y shape:", Y.shape)

model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length=max_text_len))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(2, activation='softmax'))

model.summary()

model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(0.0001),
    metrics=['accuracy']
)

history = model.fit(X, Y, batch_size=32, epochs=100, validation_split=0.1)

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def sequence_to_text(seq):
    return " ".join(reverse_word_map.get(i, "<UNK>") for i in seq)
# Out:
# Positive: 3127
# Negative: 3038
# Total: 6165
# Example word counts: [('сегодня', 1031), ('я', 2464), ('чувствую', 1160), ('радость', 255), ('и', 3205), ('внутреннее', 209), ('спокойствие', 769), ('это', 1958), ('вызывает', 540), ('у', 753)]
# First text sample: Сегодня я чувствую радость и внутреннее спокойствие. И это вызывает у меня особые чувства.
# Data shape: (6165, 100)
# X shape: (6165, 100)
# Y shape: (6165, 2)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.6852 - loss: 0.6358 - val_accuracy: 0.9611 - val_loss: 0.1323
# Epoch 2/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9553 - loss: 0.1080 - val_accuracy: 0.9660 - val_loss: 0.0765
# Epoch 3/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9658 - loss: 0.0697 - val_accuracy: 0.9692 - val_loss: 0.0579
# Epoch 4/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9727 - loss: 0.0497 - val_accuracy: 0.9708 - val_loss: 0.0557
# Epoch 5/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9824 - loss: 0.0435 - val_accuracy: 0.9741 - val_loss: 0.0476
# Epoch 6/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9809 - loss: 0.0388 - val_accuracy: 0.9838 - val_loss: 0.0442
# Epoch 7/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9852 - loss: 0.0375 - val_accuracy: 0.9692 - val_loss: 0.0590
# Epoch 8/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9859 - loss: 0.0381 - val_accuracy: 0.9773 - val_loss: 0.0417
# Epoch 9/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9932 - loss: 0.0278 - val_accuracy: 0.9773 - val_loss: 0.0389
# Epoch 10/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9938 - loss: 0.0251 - val_accuracy: 0.9806 - val_loss: 0.0366
# Epoch 11/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9989 - loss: 0.0220 - val_accuracy: 0.9806 - val_loss: 0.0341
# Epoch 12/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9991 - loss: 0.0146 - val_accuracy: 0.9838 - val_loss: 0.0312
# Epoch 13/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9806 - val_loss: 0.0312
# Epoch 14/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9998 - loss: 0.0052 - val_accuracy: 0.9806 - val_loss: 0.0308
# Epoch 15/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9854 - val_loss: 0.0286
# Epoch 16/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9789 - val_loss: 0.0308
# Epoch 17/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9854 - val_loss: 0.0286
# Epoch 18/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 7.8774e-04 - val_accuracy: 0.9870 - val_loss: 0.0287
# Epoch 19/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 7.3664e-04 - val_accuracy: 0.9822 - val_loss: 0.0293
# Epoch 20/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 1.0000 - loss: 6.2418e-04 - val_accuracy: 0.9822 - val_loss: 0.0299
# Epoch 21/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 3.9759e-04 - val_accuracy: 0.9822 - val_loss: 0.0311
# Epoch 22/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 3.2828e-04 - val_accuracy: 0.9822 - val_loss: 0.0298
# Epoch 23/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 3.0439e-04 - val_accuracy: 0.9838 - val_loss: 0.0294
# Epoch 24/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 2.9920e-04 - val_accuracy: 0.9806 - val_loss: 0.0297
# Epoch 25/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - loss: 2.1711e-04 - val_accuracy: 0.9822 - val_loss: 0.0324
# Epoch 26/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 2.9483e-04 - val_accuracy: 0.9822 - val_loss: 0.0321
# Epoch 27/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 1.6286e-04 - val_accuracy: 0.9806 - val_loss: 0.0361
# Epoch 28/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 8.5397e-04 - val_accuracy: 0.9806 - val_loss: 0.0306
# Epoch 29/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 1.3920e-04 - val_accuracy: 0.9822 - val_loss: 0.0334
# Epoch 30/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 1.0972e-04 - val_accuracy: 0.9822 - val_loss: 0.0341
# Epoch 31/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 1.0000 - loss: 8.5760e-05 - val_accuracy: 0.9822 - val_loss: 0.0320
# Epoch 32/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 7.7882e-05 - val_accuracy: 0.9822 - val_loss: 0.0335
# Epoch 33/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 7.1897e-05 - val_accuracy: 0.9806 - val_loss: 0.0316
# Epoch 34/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 6.6328e-05 - val_accuracy: 0.9806 - val_loss: 0.0317
# Epoch 35/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 1.0000 - loss: 5.5760e-05 - val_accuracy: 0.9822 - val_loss: 0.0336
# Epoch 36/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 5.8960e-05 - val_accuracy: 0.9806 - val_loss: 0.0317
# Epoch 37/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 5.0077e-05 - val_accuracy: 0.9806 - val_loss: 0.0320
# Epoch 38/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 4.6613e-05 - val_accuracy: 0.9806 - val_loss: 0.0320
# Epoch 39/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.8717e-05 - val_accuracy: 0.9822 - val_loss: 0.0335
# Epoch 40/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 3.5756e-05 - val_accuracy: 0.9806 - val_loss: 0.0321
# Epoch 41/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 3.3100e-05 - val_accuracy: 0.9822 - val_loss: 0.0330
# Epoch 42/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 2.4927e-05 - val_accuracy: 0.9806 - val_loss: 0.0328
# Epoch 43/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 2.5236e-05 - val_accuracy: 0.9806 - val_loss: 0.0329
# Epoch 44/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.4166e-05 - val_accuracy: 0.9806 - val_loss: 0.0332
# Epoch 45/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 1.0000 - loss: 2.0074e-05 - val_accuracy: 0.9822 - val_loss: 0.0346
# Epoch 46/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 1.9772e-05 - val_accuracy: 0.9806 - val_loss: 0.0335
# Epoch 47/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 1.7218e-05 - val_accuracy: 0.9822 - val_loss: 0.0343
# Epoch 48/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 1.5786e-05 - val_accuracy: 0.9806 - val_loss: 0.0335
# Epoch 49/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 1.5427e-05 - val_accuracy: 0.9806 - val_loss: 0.0332
# Epoch 50/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - loss: 1.4300e-05 - val_accuracy: 0.9806 - val_loss: 0.0338
# Epoch 51/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 1.1429e-05 - val_accuracy: 0.9822 - val_loss: 0.0344
# Epoch 52/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 1.1166e-05 - val_accuracy: 0.9822 - val_loss: 0.0343
# Epoch 53/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 9.5237e-06 - val_accuracy: 0.9822 - val_loss: 0.0352
# Epoch 54/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 8.5107e-06 - val_accuracy: 0.9822 - val_loss: 0.0354
# Epoch 55/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 9.5445e-06 - val_accuracy: 0.9822 - val_loss: 0.0347
# Epoch 56/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 8.0059e-06 - val_accuracy: 0.9822 - val_loss: 0.0363
# Epoch 57/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.5059e-06 - val_accuracy: 0.9822 - val_loss: 0.0358
# Epoch 58/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.5584e-06 - val_accuracy: 0.9806 - val_loss: 0.0351
# Epoch 59/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 1.0000 - loss: 7.6016e-06 - val_accuracy: 0.9822 - val_loss: 0.0352
# Epoch 60/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 6.0937e-06 - val_accuracy: 0.9806 - val_loss: 0.0351
# Epoch 61/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 1.0000 - loss: 5.6029e-06 - val_accuracy: 0.9822 - val_loss: 0.0377
# Epoch 62/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 5.2310e-06 - val_accuracy: 0.9822 - val_loss: 0.0357
# Epoch 63/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 3.7131e-06 - val_accuracy: 0.9822 - val_loss: 0.0375
# Epoch 64/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 4.0571e-06 - val_accuracy: 0.9806 - val_loss: 0.0352
# Epoch 65/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.2550e-06 - val_accuracy: 0.9806 - val_loss: 0.0358
# Epoch 66/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - loss: 3.2368e-06 - val_accuracy: 0.9806 - val_loss: 0.0359
# Epoch 67/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.2237e-06 - val_accuracy: 0.9806 - val_loss: 0.0355
# Epoch 68/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.8842e-06 - val_accuracy: 0.9806 - val_loss: 0.0357
# Epoch 69/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 1.0000 - loss: 2.7290e-06 - val_accuracy: 0.9806 - val_loss: 0.0359
# Epoch 70/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.3793e-06 - val_accuracy: 0.9806 - val_loss: 0.0365
# Epoch 71/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - loss: 2.0238e-06 - val_accuracy: 0.9822 - val_loss: 0.0374
# Epoch 72/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 1.9342e-06 - val_accuracy: 0.9806 - val_loss: 0.0366
# Epoch 73/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 1.0000 - loss: 1.5825e-06 - val_accuracy: 0.9822 - val_loss: 0.0378
# Epoch 74/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 1.8062e-06 - val_accuracy: 0.9806 - val_loss: 0.0367
# Epoch 75/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 1.4840e-06 - val_accuracy: 0.9806 - val_loss: 0.0375
# Epoch 76/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 1.0000 - loss: 1.3291e-06 - val_accuracy: 0.9822 - val_loss: 0.0380
# Epoch 77/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 1.2011e-06 - val_accuracy: 0.9822 - val_loss: 0.0391
# Epoch 78/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 1.4559e-06 - val_accuracy: 0.9806 - val_loss: 0.0371
# Epoch 79/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 9.6215e-07 - val_accuracy: 0.9806 - val_loss: 0.0378
# Epoch 80/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 8.4851e-07 - val_accuracy: 0.9822 - val_loss: 0.0394
# Epoch 81/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 7.9620e-07 - val_accuracy: 0.9806 - val_loss: 0.0376
# Epoch 82/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 1.0000 - loss: 7.9933e-07 - val_accuracy: 0.9806 - val_loss: 0.0383
# Epoch 83/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 6.7052e-07 - val_accuracy: 0.9822 - val_loss: 0.0390
# Epoch 84/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 6.9438e-07 - val_accuracy: 0.9806 - val_loss: 0.0378
# Epoch 85/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 6.0968e-07 - val_accuracy: 0.9822 - val_loss: 0.0390
# Epoch 86/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 1.0000 - loss: 6.0807e-07 - val_accuracy: 0.9822 - val_loss: 0.0392
# Epoch 87/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 1.0000 - loss: 5.7147e-07 - val_accuracy: 0.9806 - val_loss: 0.0389
# Epoch 88/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 5.8740e-07 - val_accuracy: 0.9806 - val_loss: 0.0391
# Epoch 89/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.5277e-07 - val_accuracy: 0.9822 - val_loss: 0.0402
# Epoch 90/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.1652e-07 - val_accuracy: 0.9822 - val_loss: 0.0407
# Epoch 91/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.9713e-07 - val_accuracy: 0.9806 - val_loss: 0.0394
# Epoch 92/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 1.0000 - loss: 3.2809e-07 - val_accuracy: 0.9822 - val_loss: 0.0387
# Epoch 93/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 2.8201e-07 - val_accuracy: 0.9822 - val_loss: 0.0404
# Epoch 94/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.8784e-07 - val_accuracy: 0.9806 - val_loss: 0.0395
# Epoch 95/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.5266e-07 - val_accuracy: 0.9822 - val_loss: 0.0413
# Epoch 96/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.6884e-07 - val_accuracy: 0.9822 - val_loss: 0.0426
# Epoch 97/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 1.0000 - loss: 2.4618e-07 - val_accuracy: 0.9822 - val_loss: 0.0398
# Epoch 98/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 1.9551e-07 - val_accuracy: 0.9822 - val_loss: 0.0420
# Epoch 99/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 2.1596e-07 - val_accuracy: 0.9822 - val_loss: 0.0412
# Epoch 100/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.0786e-07 - val_accuracy: 0.9822 - val_loss: 0.0410

# %% [markdown]
# ### We test on 1st couple for negatives, then positive, and mixes with bias on positive or negative(more negative sentences than positive ones, for example)

# %%
test_files = [
    "test_1_neg.txt",
    "test_2_neg.txt",
    "test_3_pos.txt",
    "test_4_pos.txt",
    "test_5_mix_neg.txt",
    "test_6_mix_pos.txt",
]

results = []

for file in test_files:

    with open(file, "r", encoding="utf-8") as f:
        lines = f.readlines()
        lines[0] = lines[0].replace("\ufeff", "")

    text = " ".join(line.strip() for line in lines)

    seq = tokenizer.texts_to_sequences([text])
    seq_pad = pad_sequences(seq, maxlen=max_text_len)

    pred = model.predict(seq_pad, verbose=0)[0]
    pred_class = int(np.argmax(pred))

    results.append({
        "file": file,
        "predicted_class": pred_class,
        "raw_output": pred
    })

df_results = pd.DataFrame(results)
df_results
# Out:
#                  file  predicted_class                   raw_output
# 0      test_1_neg.txt                1   [0.0001213456, 0.99987864]
# 1      test_2_neg.txt                1  [9.3736355e-07, 0.99999905]
# 2      test_3_pos.txt                0         [1.0, 6.0736403e-09]
# 3      test_4_pos.txt                0          [1.0, 6.146711e-09]
# 4  test_5_mix_neg.txt                1      [0.12940292, 0.8705971]
# 5  test_6_mix_pos.txt                0          [1.0, 3.554624e-08]

# %% [markdown]
# ### Validating, with free-hand text(My own)

# %%
def predict_sentiment(text: str):

    seq = tokenizer.texts_to_sequences([text])
    seq_pad = pad_sequences(seq, maxlen=max_text_len)

    prediction = model.predict(seq_pad)[0]
    label = np.argmax(prediction)

    if label == 1:
        sentiment = "NEGATIVE"
    else:
        sentiment = "POSITIVE"

    return sentiment, prediction

sentiment, raw = predict_sentiment("Куда катится мир?")
print(sentiment)
print(raw)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NEGATIVE
# [2.0656373e-06 9.9999797e-01]
