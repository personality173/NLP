# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import re

from tensorflow.keras.layers import Dense, LSTM, Input, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
with open('new_train_data_true.txt', 'r', encoding='utf-8') as f:
    texts_true = f.readlines()
    texts_true[0] = texts_true[0].replace('\ufeff', '') #убираем первый невидимый символ

with open('new_train_data_false.txt', 'r', encoding='utf-8') as f:
    texts_false = f.readlines()
    texts_false[0] = texts_false[0].replace('\ufeff', '') #убираем первый невидимый символ

texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false
print(count_true, count_false, total_lines)


maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])


max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(data_pad)

print( list(tokenizer.word_index.items()) )


X = data_pad
Y = np.array([[1, 0]]*count_true + [[0, 1]]*count_false)
print(X.shape, Y.shape)

indeces = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indeces]
Y = Y[indeces]


model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length = max_text_len))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adam(0.0001))

history = model.fit(X, Y, batch_size=32, epochs=50)

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return(words)

t = "Сегодня была страшная и плохая погода".lower()
# t = "Я никогда не сяду за руль, это же смертельно опасно! ".lower()


data = tokenizer.texts_to_sequences([t])
data_pad = pad_sequences(data, maxlen=max_text_len)
print( sequence_to_text(data[0]) )

res = model.predict(data_pad)
print(res, np.argmax(res), sep='\n')
# Out:
# 81 81 162
# [('сегодня', 36), ('была', 39), ('страшная', 50), ('и', 56), ('плохая', 47), ('погода', 65), ('очень', 3), ('это', 17), ('то', 1), ('что', 1)]
# сегодня была страшная и плохая погода
#
# [[  0   0   0 ...   2   4   1]
#  [  0   0   0 ...   5  16   3]
#  [  0   0   0 ...  46  22  47]
#  ...
#  [  0   0   0 ... 224  14 225]
#  [  0   0   0 ...   2 226  40]
#  [  0   0   0 ...   2 227 228]]
# [('погода', 1), ('и', 2), ('страшная', 3), ('плохая', 4), ('была', 5), ('сегодня', 6), ('это', 7), ('хорошая', 8), ('счастье', 9), ('радость', 10), ('прекрасная', 11), ('солнечный', 12), ('великолепная', 13), ('в', 14), ('день', 15), ('очень', 16), ('вокруг', 17), ('лучше', 18), ('всех', 19), ('для', 20), ('на', 21), ('мне', 22), ('меня', 23), ('атмосфера', 24), ('мой', 25), ('всегда', 26), ('удача', 27), ('успех', 28), ('победа', 29), ('природа', 30), ('картина', 31), ('любовь', 32), ('солнце', 33), ('тепло', 34), ('добрая', 35), ('свет', 36), ('каждого', 37), ('мира', 38), ('с', 39), ('игра', 40), ('книга', 41), ('смех', 42), ('о', 43), ('жизни', 44), ('то', 45), ('что', 46), ('нравится', 47), ('радует', 48), ('нормально', 49), ('просто', 50), ('я', 51), ('люблю', 52), ('когда', 53), ('выбор', 54), ('делает', 55), ('буря', 56), ('везде', 57), ('самая', 58), ('ситуация', 59), ('прекрасно', 60), ('супер', 61), ('ночь', 62), ('тут', 63), ('исключительно', 64), ('со', 65), ('мной', 66), ('стиль', 67), ('невероятно', 68), ('хорошо', 69), ('позитивно', 70), ('темная', 71), ('сейчас', 72), ('среда', 73), ('по', 74), ('душе', 75), ('весело', 76), ('гроза', 77), ('приносит', 78), ('осень', 79), ('зима', 80), ('весна', 81), ('жара', 82), ('слякоть', 83), ('весь', 84), ('метель', 85), ('чем', 86), ('туча', 87), ('утром', 88), ('дымка', 89), ('круто', 90), ('класс', 91), ('видимость', 92), ('ужасно', 93), ('энергетика', 94), ('вдохновляет', 95), ('мотивирует', 96), ('навсегда', 97), ('холодная', 98), ('сырая', 99), ('прекрасный', 100), ('отлично', 101), ('светит', 102), ('ярко', 103), ('великолепный', 104), ('улыбки', 105), ('жизнь', 106), ('переполняет', 107), ('красота', 108), ('есть', 109), ('у', 110), ('новость', 111), ('нас', 112), ('светлая', 113), ('даль', 114), ('веселье', 115), ('доме', 116), ('луч', 117), ('окне', 118), ('жить', 119), ('любить', 120), ('работа', 121), ('отдых', 122), ('мечта', 123), ('сбылась', 124), ('дня', 125), ('зайчик', 126), ('стене', 127), ('музыка', 128), ('звучит', 129), ('быть', 130), ('вместе', 131), ('компания', 132), ('друзей', 133), ('возможность', 134), ('встречи', 135), ('тобой', 136), ('берег', 137), ('моря', 138), ('актеров', 139), ('простых', 140), ('вещах', 141), ('идея', 142), ('пришла', 143), ('столе', 144), ('творчества', 145), ('созидания', 146), ('парке', 147), ('команды', 148), ('дарить', 149), ('добро', 150), ('шутка', 151), ('песня', 152), ('любви', 153), ('познания', 154), ('круг', 155), ('небо', 156), ('еда', 157), ('напитки', 158), ('видеть', 159), ('красоту', 160), ('привычка', 161), ('учиться', 162), ('цель', 163), ('достижения', 164), ('цели', 165), ('ясный', 166), ('горизонт', 167), ('архитектура', 168), ('города', 169), ('гармония', 170), ('души', 171), ('память', 172), ('прошлом', 173), ('надежда', 174), ('будущее', 175), ('общения', 176), ('близкими', 177), ('ветер', 178), ('перемен', 179), ('наука', 180), ('техника', 181), ('здоровье', 182), ('всем', 183), ('оценка', 184), ('за', 185), ('труд', 186), ('школа', 187), ('открытия', 188), ('нового', 189), ('теплый', 190), ('прием', 191), ('организация', 192), ('праздника', 193), ('мир', 194), ('дому', 195), ('традиция', 196), ('семьи', 197), ('коллекция', 198), ('цветов', 199), ('спортивных', 200), ('побед', 201), ('яркий', 202), ('цвет', 203), ('роль', 204), ('кино', 205), ('свобода', 206), ('выбора', 207), ('верная', 208), ('дружба', 209), ('чистая', 210), ('глазах', 211), ('жаркий', 212), ('полдень', 213), ('умная', 214), ('мысль', 215), ('рядом', 216), ('полезная', 217), ('вещь', 218), ('сказка', 219), ('детский', 220), ('тихий', 221), ('вечер', 222), ('мудрая', 223), ('покой', 224), ('сердце', 225), ('честная', 226), ('милая', 227), ('улыбка', 228)]
# (162, 10) (162, 2)
# c:\Users\denkh\Downloads\KBTU\NLP\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5123 - loss: 0.6927
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7716 - loss: 0.6894
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8457 - loss: 0.6862
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6111 - loss: 0.6836
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5741 - loss: 0.6802
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5741 - loss: 0.6766
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5679 - loss: 0.6721
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5309 - loss: 0.6675
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5247 - loss: 0.6629
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5679 - loss: 0.6554
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5926 - loss: 0.6473
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5926 - loss: 0.6382
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5926 - loss: 0.6264
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5926 - loss: 0.6133
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6235 - loss: 0.5970
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7284 - loss: 0.5759
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8765 - loss: 0.5501
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9074 - loss: 0.5195
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9815 - loss: 0.4848
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.4463
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.4065
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9877 - loss: 0.3611
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9815 - loss: 0.3128
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2690
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.2268
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1891
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1546
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1234
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0973
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0841
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0648
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0519
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0434
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0341
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0216
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0184
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0149
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9938 - loss: 0.0196
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0113
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0031
# ['сегодня', 'была', 'страшная', 'и', 'плохая', 'погода']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# [[9.9953806e-01 4.6195756e-04]]
# 0
